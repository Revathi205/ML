# %%
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Generate some sample data
# Let's create data with 3 features, where one is highly correlated with another
X = np.random.rand(100, 3) * 10
X[:, 2] = X[:, 0] * 0.5 + np.random.randn(100) # Feature 2 is dependent on Feature 0

print("Original data shape:", X.shape)

# Initialize PCA to reduce to 2 components
pca = PCA(n_components=2)

# Fit PCA on the data and transform it
X_reduced = pca.fit_transform(X)

print("Reduced data shape:", X_reduced.shape)
print("\nFirst 5 rows of original data:\n", X[:5])
print("\nFirst 5 rows of PCA-reduced data:\n", X_reduced[:5])

# Optionally, visualize the explained variance ratio
# This shows how much variance each principal component captures
explained_variance = pca.explained_variance_ratio_
print("\nExplained variance ratio by each component:", explained_variance)
print("Total explained variance:", explained_variance.sum())

# Plotting the reduced data (if 2D)
plt.figure(figsize=(8, 6))
plt.scatter(X_reduced[:, 0], X_reduced[:, 1])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Reduced Data (2 Components)')
plt.grid(True)
plt.show()
# Out:
# Original data shape: (100, 3)
# Reduced data shape: (100, 2)
#
# First 5 rows of original data:
#  [[3.72220995 9.34903153 0.01164987]
#  [5.08714109 5.52164995 1.95762612]
#  [4.32330819 1.84635519 2.36394802]
#  [3.79830701 9.20599525 1.17537438]
#  [3.29863182 5.65408196 3.32725138]]
#
# First 5 rows of PCA-reduced data:
#  [[-2.04312319  3.92047194]
#  [ 0.08468424  0.10705927]
#  [-0.38738563 -3.56816232]
#  [-1.43758945  3.78371007]
#  [-0.86995231  0.24168939]]
#
# Explained variance ratio by each component: [0.50510314 0.43934263]
# Total explained variance: 0.9444457710097671

# %%
# Dimensionality Reduction using PCA (Readable Output)

from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import pandas as pd

# Load Iris dataset
data = load_iris()
X = data.data

# Standardize data
X_scaled = StandardScaler().fit_transform(X)

# Apply PCA (reduce 4 features to 2 principal components)
pca = PCA(n_components=2)
X_reduced = pca.fit_transform(X_scaled)

# Convert result into table
df = pd.DataFrame(X_reduced, columns=["Principal Component 1", "Principal Component 2"])

# Print shapes
print("Original Data Shape :", X.shape)
print("Reduced Data Shape  :", X_reduced.shape)

# Show explained variance
print("\nVariance Captured by Components:")
print("PC1 =", round(pca.explained_variance_ratio_[0] * 100, 2), "%")
print("PC2 =", round(pca.explained_variance_ratio_[1] * 100, 2), "%")

# Show first 10 reduced rows
print("\nFirst 10 Rows of Reduced Data:")
print(df.head(10))
# Out:
# Original Data Shape : (150, 4)
# Reduced Data Shape  : (150, 2)
#
# Variance Captured by Components:
# PC1 = 72.96 %
# PC2 = 22.85 %
#
# First 10 Rows of Reduced Data:
#    Principal Component 1  Principal Component 2
# 0              -2.264703               0.480027
# 1              -2.080961              -0.674134
# 2              -2.364229              -0.341908
# 3              -2.299384              -0.597395
# 4              -2.389842               0.646835
# 5              -2.075631               1.489178
# 6              -2.444029               0.047644
# 7              -2.232847               0.223148
# 8              -2.334640              -1.115328
# 9              -2.184328              -0.469014
